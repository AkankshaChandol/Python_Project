# %%
import pandas as pd

# %%
#Load alcohol world alcohol datase
df = pd.read_csv("C:/Users/Lenovo/Downloads/world_alcohol_comsumption.csv")

# %%
df
# Out:
#     Year       WHO region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 2   1985           Africa                           Cte d'Ivoire
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# ..   ...              ...                                    ...
# 95  1984           Africa                                  Niger
# 96  1985           Europe                             Luxembourg
# 97  1984  South-East Asia                              Indonesia
# 98  1984           Africa                      Equatorial Guinea
# 99  1985  South-East Asia  Democratic People's Republic of Korea
#
#    Beverage Types  Display Value
# 0            Wine           0.00
# 1           Other           0.50
# 2            Wine           1.62
# 3            Beer           4.27
# 4            Beer           1.98
# ..            ...            ...
# 95          Other           0.00
# 96           Wine           7.38
# 97           Wine           0.00
# 98           Wine           0.00
# 99           Wine           0.00
#
# [100 rows x 5 columns]

# %%
#1

df[(df.Year == 1987) | (df.Year == 1989)]
# Out:
#     Year             WHO region                           Country  \
# 4   1987               Americas             Saint Kitts and Nevis
# 5   1987               Americas                         Guatemala
# 6   1987                 Africa                         Mauritius
# 10  1987                 Africa                          Botswana
# 11  1989               Americas                         Guatemala
# 15  1987                 Africa                     Guinea-Bissau
# 17  1989                 Africa                        Seychelles
# 21  1989               Americas                        Costa Rica
# 28  1987        Western Pacific                          Viet Nam
# 32  1989                 Africa                         Mauritius
# 36  1987  Eastern Mediterranean                             Egypt
# 38  1987  Eastern Mediterranean                             Qatar
# 39  1987                 Africa                      Burkina Faso
# 40  1987                 Europe                           Austria
# 45  1989                 Africa                          Zimbabwe
# 46  1987               Americas               Trinidad and Tobago
# 48  1987               Americas                         Nicaragua
# 51  1987                 Europe                           Finland
# 55  1989               Americas                          Suriname
# 56  1987        Western Pacific                          Viet Nam
# 57  1989                 Europe                           Croatia
# 59  1989  Eastern Mediterranean              Syrian Arab Republic
# 60  1987  Eastern Mediterranean        Iran (Islamic Republic of)
# 62  1987               Americas                          Suriname
# 64  1989               Americas  Bolivia (Plurinational State of)
# 65  1989  Eastern Mediterranean                           Somalia
# 66  1987  Eastern Mediterranean                              Iraq
# 67  1989                 Africa                           Namibia
# 68  1989                 Africa                            Uganda
# 72  1987                 Africa                        Mauritania
# 75  1989  Eastern Mediterranean                       Afghanistan
# 78  1989               Americas                           Jamaica
# 79  1989                 Europe                           Finland
# 82  1987                 Europe                           Ireland
# 87  1989  Eastern Mediterranean                              Iraq
# 88  1987  Eastern Mediterranean                           Lebanon
# 90  1989                 Africa                            Malawi
# 91  1989                 Europe                          Bulgaria
# 93  1987                 Africa                        Madagascar
#
#    Beverage Types  Display Value
# 4            Beer           1.98
# 5           Other           0.00
# 6            Wine           0.13
# 10           Wine           0.20
# 11           Beer           0.62
# 15           Wine           0.07
# 17           Beer           2.23
# 21        Spirits           4.51
# 28           Beer           0.11
# 32           Beer           1.60
# 36           Beer           0.07
# 38          Other           0.00
# 39        Spirits           0.01
# 40        Spirits           1.90
# 45           Beer           0.19
# 46        Spirits           2.26
# 48           Beer           0.70
# 51           Beer           3.88
# 55           Wine           0.04
# 56           Wine           0.00
# 57           Wine           5.10
# 59          Other           0.00
# 60          Other           0.00
# 62          Other           0.00
# 64           Beer           1.26
# 65           Beer           0.00
# 66           Wine           0.01
# 67           Beer           0.00
# 68           Beer           0.12
# 72          Other           0.00
# 75          Other           0.00
# 78          Other           0.00
# 79          Other           2.09
# 82        Spirits           2.25
# 87           Wine           0.01
# 88           Beer           0.42
# 90           Wine           0.01
# 91           Beer           4.43
# 93          Other            NaN

# %%
#2
res = df[df['Year'] == 1987].where(( df['WHO region'] =='Western Pacific')
           & (df['Country'] == 'Viet Nam'))
res
# Out:
#       Year       WHO region   Country Beverage Types  Display Value
# 4      NaN              NaN       NaN            NaN            NaN
# 5      NaN              NaN       NaN            NaN            NaN
# 6      NaN              NaN       NaN            NaN            NaN
# 10     NaN              NaN       NaN            NaN            NaN
# 15     NaN              NaN       NaN            NaN            NaN
# 28  1987.0  Western Pacific  Viet Nam           Beer           0.11
# 36     NaN              NaN       NaN            NaN            NaN
# 38     NaN              NaN       NaN            NaN            NaN
# 39     NaN              NaN       NaN            NaN            NaN
# 40     NaN              NaN       NaN            NaN            NaN
# 46     NaN              NaN       NaN            NaN            NaN
# 48     NaN              NaN       NaN            NaN            NaN
# 51     NaN              NaN       NaN            NaN            NaN
# 56  1987.0  Western Pacific  Viet Nam           Wine           0.00
# 60     NaN              NaN       NaN            NaN            NaN
# 62     NaN              NaN       NaN            NaN            NaN
# 66     NaN              NaN       NaN            NaN            NaN
# 72     NaN              NaN       NaN            NaN            NaN
# 82     NaN              NaN       NaN            NaN            NaN
# 88     NaN              NaN       NaN            NaN            NaN
# 93     NaN              NaN       NaN            NaN            NaN

# %%
#2
res = df[df['Year'] == 1987].where(( df['WHO region'] =='Western Pacific')
           & (df['Country'] == 'Viet Nam'))
res = res.dropna() # to drop NAN value
res
# Out:
#       Year       WHO region   Country Beverage Types  Display Value
# 28  1987.0  Western Pacific  Viet Nam           Beer           0.11
# 56  1987.0  Western Pacific  Viet Nam           Wine           0.00

# %%
#2
import matplotlib.pyplot as plt
plt.bar ('Beverage Types', 'Display Value', data = res1, label = '1987', color ='Blue')
plt.show()

# %%
#2
import matplotlib.pyplot as plt
plt.barh ('Beverage Types', 'Display Value', data = res1, label = '1987', color ='Orange')#barh means horizontal graph
plt.xlabel('ALCOHOL CONSUMPTION')
plt.ylabel('WESTERN PACIFIC - VIET NAM')
plt.show()

# %%
#2
import matplotlib.pyplot as plt
plt.bar ('Beverage Types', 'Display Value', data = res1, label = '1987', color ='Orange')#barh means horizontal graph
plt.xlabel('ALCOHOL CONSUMPTION')
plt.ylabel('WESTERN PACIFIC - VIET NAM')
plt.show()

# %%
df
# Out:
#     Year       WHO region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 2   1985           Africa                           Cte d'Ivoire
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# ..   ...              ...                                    ...
# 95  1984           Africa                                  Niger
# 96  1985           Europe                             Luxembourg
# 97  1984  South-East Asia                              Indonesia
# 98  1984           Africa                      Equatorial Guinea
# 99  1985  South-East Asia  Democratic People's Republic of Korea
#
#    Beverage Types  Display Value
# 0            Wine           0.00
# 1           Other           0.50
# 2            Wine           1.62
# 3            Beer           4.27
# 4            Beer           1.98
# ..            ...            ...
# 95          Other           0.00
# 96           Wine           7.38
# 97           Wine           0.00
# 98           Wine           0.00
# 99           Wine           0.00
#
# [100 rows x 5 columns]

# %%
res = df[(df['Year'] == 1986) | (df['Year'] == 1989)].where ((df['WHO region'] == 'Americas') | (df['WHO region'] == 'Europe'))
res = res.dropna()

# %% [raw]
# res1

# %%
res
# Out:
#       Year WHO region                           Country Beverage Types  \
# 1   1986.0   Americas                           Uruguay          Other
# 3   1986.0   Americas                          Colombia           Beer
# 8   1986.0   Americas               Antigua and Barbuda        Spirits
# 11  1989.0   Americas                         Guatemala           Beer
# 21  1989.0   Americas                        Costa Rica        Spirits
# 34  1986.0     Europe                Russian Federation           Wine
# 37  1986.0     Europe                            Sweden           Beer
# 41  1986.0     Europe                    Czech Republic           Beer
# 47  1986.0   Americas                            Mexico          Other
# 49  1986.0     Europe                             Malta           Wine
# 55  1989.0   Americas                          Suriname           Wine
# 57  1989.0     Europe                           Croatia           Wine
# 64  1989.0   Americas  Bolivia (Plurinational State of)           Beer
# 74  1986.0   Americas  Bolivia (Plurinational State of)        Spirits
# 78  1989.0   Americas                           Jamaica          Other
# 79  1989.0     Europe                           Finland          Other
# 86  1986.0   Americas                           Bahamas           Wine
# 91  1989.0     Europe                          Bulgaria           Beer
#
#     Display Value
# 1            0.50
# 3            4.27
# 8            1.55
# 11           0.62
# 21           4.51
# 34           0.80
# 37           3.04
# 41           6.82
# 47           0.04
# 49           1.49
# 55           0.04
# 57           5.10
# 64           1.26
# 74           2.06
# 78           0.00
# 79           2.09
# 86           1.83
# 91           4.43

# %% [raw]
# res

# %%
res2 = res[res['Year']==1989]

# %%
res2
# Out:
#       Year WHO region                           Country Beverage Types  \
# 11  1989.0   Americas                         Guatemala           Beer
# 21  1989.0   Americas                        Costa Rica        Spirits
# 55  1989.0   Americas                          Suriname           Wine
# 57  1989.0     Europe                           Croatia           Wine
# 64  1989.0   Americas  Bolivia (Plurinational State of)           Beer
# 78  1989.0   Americas                           Jamaica          Other
# 79  1989.0     Europe                           Finland          Other
# 91  1989.0     Europe                          Bulgaria           Beer
#
#     Display Value
# 11           0.62
# 21           4.51
# 55           0.04
# 57           5.10
# 64           1.26
# 78           0.00
# 79           2.09
# 91           4.43

# %%
res
# Out:
#       Year       WHO region   Country Beverage Types  Display Value
# 28  1987.0  Western Pacific  Viet Nam           Beer           0.11
# 56  1987.0  Western Pacific  Viet Nam           Wine           0.00

# %%
res1 = res[res['Year'] == 1986]
res1
# Out:
#       Year WHO region                           Country Beverage Types  \
# 1   1986.0   Americas                           Uruguay          Other
# 3   1986.0   Americas                          Colombia           Beer
# 8   1986.0   Americas               Antigua and Barbuda        Spirits
# 34  1986.0     Europe                Russian Federation           Wine
# 37  1986.0     Europe                            Sweden           Beer
# 41  1986.0     Europe                    Czech Republic           Beer
# 47  1986.0   Americas                            Mexico          Other
# 49  1986.0     Europe                             Malta           Wine
# 74  1986.0   Americas  Bolivia (Plurinational State of)        Spirits
# 86  1986.0   Americas                           Bahamas           Wine
#
#     Display Value
# 1            0.50
# 3            4.27
# 8            1.55
# 34           0.80
# 37           3.04
# 41           6.82
# 47           0.04
# 49           1.49
# 74           2.06
# 86           1.83

# %%
#Display bar charts for 1986
import matplotlib.pyplot as plt
plt.bar('WHO region','Display Value', data =res1, labeL = '1986', color  = 'Blue')
plt.xlabel('WHO region')
plt.ylabel('ALCOHOL CONSUMPTION')
plt.legend()
plt.show()
# Out:
# <ipython-input-41-beb8ce1bcfc9>:3: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.bar('WHO region','Display Value', data =res1, labeL = '1986', color  = 'Blue')

# %%
#Display bar charts for 1986
import matplotlib.pyplot as plt
plt.bar('WHO region','Display Value', data =res1, labeL = '1989', color  = 'Cyan')
plt.xlabel('WHO region')
plt.ylabel('ALCOHOL CONSUMPTION')
plt.legend()
plt.show()
# Out:
# <ipython-input-42-7981a1d6ed2f>:3: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   plt.bar('WHO region','Display Value', data =res1, labeL = '1989', color  = 'Cyan')

# %%
#4
res = df[(df['Year']==1986) | (df['Year']==1989). where ((df['WHO region'] == 'Americas') | (df['WHO region'] == 'Europe'))][['WHO region','Country','Beverage Types']]

# %%
res
# Out:
#                WHO region                           Country Beverage Types
# 0         Western Pacific                          Viet Nam           Wine
# 1                Americas                           Uruguay          Other
# 3                Americas                          Colombia           Beer
# 8                Americas               Antigua and Barbuda        Spirits
# 11               Americas                         Guatemala           Beer
# 20        South-East Asia                           Myanmar           Wine
# 21               Americas                        Costa Rica        Spirits
# 29                 Europe                             Italy          Other
# 30                 Africa                      Sierra Leone          Other
# 31        Western Pacific  Micronesia (Federated States of)           Wine
# 34                 Europe                Russian Federation           Wine
# 37                 Europe                            Sweden           Beer
# 41                 Europe                    Czech Republic           Beer
# 47               Americas                            Mexico          Other
# 49                 Europe                             Malta           Wine
# 52  Eastern Mediterranean                      Saudi Arabia           Wine
# 55               Americas                          Suriname           Wine
# 57                 Europe                           Croatia           Wine
# 64               Americas  Bolivia (Plurinational State of)           Beer
# 69                 Africa                              Togo        Spirits
# 70                 Africa                        Madagascar        Spirits
# 73  Eastern Mediterranean                          Pakistan          Other
# 74               Americas  Bolivia (Plurinational State of)        Spirits
# 78               Americas                           Jamaica          Other
# 79                 Europe                           Finland          Other
# 83                 Europe                           Ukraine          Other
# 84        South-East Asia                         Sri Lanka          Other
# 86               Americas                           Bahamas           Wine
# 89  Eastern Mediterranean                           Lebanon           Wine
# 91                 Europe                          Bulgaria           Beer
# 92                 Africa                           Eritrea        Spirits

# %%
#5
res  = df[(df['Display Value'] >=5) & (df['Beverage Types'] == 'Beer')]
res
# Out:
#     Year WHO region         Country Beverage Types  Display Value
# 41  1986     Europe  Czech Republic           Beer           6.82

# %%
#6
res1 = df[(df['Display Value']>=4) & (df['Beverage Types']=='Beer')]['Display Value'] #to dispaly a particular column you can write this in [] and for more than 1 column we can write in list like[[]]
res2 = df[(df['Display Value']>=4) & (df['Beverage Types']=='Wine')]['Display Value']
res3 = df[(df['Display Value']>=4) & (df['Beverage Types']=='Spirits')]['Display Value']
print(res1,res2,res3)
# Out:
# 3     4.27
# 41    6.82
# 91    4.43
# Name: Display Value, dtype: float64 57    5.10
# 96    7.38
# Name: Display Value, dtype: float64 21    4.51
# Name: Display Value, dtype: float64

# %%
plt.pie(res1, shadow = True, autopct = '%.1f%%')#autopct means automatically calculate percentage
plt.show()
plt.pie(res2, shadow =True, autopct  ='%.1f%%')
plt.show()
plt.pie(res3, shadow = True, autopct = '%.1f%%')
plt.show()

# %%
#7
res= df.loc[0:15, ['WHO region','Beverage Types']]
res
#same can be written using iloc
#res=df.iloc[0:16, [1,3]]
#res
# Out:
#                WHO region Beverage Types
# 0         Western Pacific           Wine
# 1                Americas          Other
# 2                  Africa           Wine
# 3                Americas           Beer
# 4                Americas           Beer
# 5                Americas          Other
# 6                  Africa           Wine
# 7                  Africa        Spirits
# 8                Americas        Spirits
# 9                  Africa          Other
# 10                 Africa           Wine
# 11               Americas           Beer
# 12        Western Pacific           Beer
# 13  Eastern Mediterranean          Other
# 14        Western Pacific        Spirits
# 15                 Africa           Wine

# %%
#8
res = df['WHO region']
res1  = res.str.contains('Ea')
len(df[res1])
#n = len(res1)
#n
#But the output is showing true as well as false records we want only true recoords
#so use len(df[res1])
# Out:
# 22

# %%
#9
# renaming the colum
df1  = df.rename(columns ={'WHO region':'WHO_region'})
df1.query("WHO_region in ['Africa','Eastern Mediterranean','Europe']")#in query we can give only one woed column name if we use WHO region it will take as two columns
# Out:
#     Year WHO_region            Country Beverage Types  Display Value
# 2   1985     Africa       Cte d'Ivoire           Wine           1.62
# 6   1987     Africa          Mauritius           Wine           0.13
# 7   1985     Africa             Angola        Spirits           0.39
# 9   1984     Africa            Nigeria          Other           6.10
# 10  1987     Africa           Botswana           Wine           0.20
# ..   ...        ...                ...            ...            ...
# 93  1987     Africa         Madagascar          Other            NaN
# 94  1985     Europe            Ukraine        Spirits           3.06
# 95  1984     Africa              Niger          Other           0.00
# 96  1985     Europe         Luxembourg           Wine           7.38
# 98  1984     Africa  Equatorial Guinea           Wine           0.00
#
# [69 rows x 5 columns]

# %%
#10
df1.query('WHO_region not in["Africa","Eastern Mediterranean","Europe"]')
# Out:
#     Year       WHO_region                                Country  \
# 0   1986  Western Pacific                               Viet Nam
# 1   1986         Americas                                Uruguay
# 3   1986         Americas                               Colombia
# 4   1987         Americas                  Saint Kitts and Nevis
# 5   1987         Americas                              Guatemala
# 8   1986         Americas                    Antigua and Barbuda
# 11  1989         Americas                              Guatemala
# 12  1985  Western Pacific       Lao People's Democratic Republic
# 14  1985  Western Pacific                               Viet Nam
# 16  1984         Americas                             Costa Rica
# 20  1986  South-East Asia                                Myanmar
# 21  1989         Americas                             Costa Rica
# 28  1987  Western Pacific                               Viet Nam
# 31  1986  Western Pacific       Micronesia (Federated States of)
# 35  1985         Americas                  Saint Kitts and Nevis
# 43  1984  Western Pacific                                  China
# 46  1987         Americas                    Trinidad and Tobago
# 47  1986         Americas                                 Mexico
# 48  1987         Americas                              Nicaragua
# 54  1984         Americas                            El Salvador
# 55  1989         Americas                               Suriname
# 56  1987  Western Pacific                               Viet Nam
# 61  1984  Western Pacific                       Papua New Guinea
# 62  1987         Americas                               Suriname
# 64  1989         Americas       Bolivia (Plurinational State of)
# 74  1986         Americas       Bolivia (Plurinational State of)
# 78  1989         Americas                                Jamaica
# 84  1986  South-East Asia                              Sri Lanka
# 86  1986         Americas                                Bahamas
# 97  1984  South-East Asia                              Indonesia
# 99  1985  South-East Asia  Democratic People's Republic of Korea
#
#    Beverage Types  Display Value
# 0            Wine           0.00
# 1           Other           0.50
# 3            Beer           4.27
# 4            Beer           1.98
# 5           Other           0.00
# 8         Spirits           1.55
# 11           Beer           0.62
# 12           Beer           0.00
# 14        Spirits           0.05
# 16           Wine           0.06
# 20           Wine           0.00
# 21        Spirits           4.51
# 28           Beer           0.11
# 31           Wine           0.00
# 35        Spirits           2.24
# 43           Wine           0.03
# 46        Spirits           2.26
# 47          Other           0.04
# 48           Beer           0.70
# 54        Spirits           1.81
# 55           Wine           0.04
# 56           Wine           0.00
# 61        Spirits           0.08
# 62          Other           0.00
# 64           Beer           1.26
# 74        Spirits           2.06
# 78          Other           0.00
# 84          Other           0.00
# 86           Wine           1.83
# 97           Wine           0.00
# 99           Wine           0.00

# %%
#12
res1 = df[(df['Beverage Types']=='Wine') & (df['Display Value']>2)]
res1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-90-84ef81d25d0c> in <module>
#       1 #12
# ----> 2 res1 = df[(df['Beverage Types']=='Wine') & (df['Display Value']>2)]
#       3 res1
#
# TypeError: list indices must be integers or slices, not str

# %%
#13
lst = list(range(0,100,10))
rows = df.iloc[lst, :]
rows
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-100-fbd57a96e2c2> in <module>
#       1 #13
#       2 lst = list(range(0,100,10))
# ----> 3 rows = df.iloc[lst, :]
#       4 rows
#
# AttributeError: 'list' object has no attribute 'iloc'

# %%
#14
lst = list(range(0, 10))
rows = df.loc[lst, ['Year', 'Country']]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-102-ec966d548436> in <module>
#       1 #14
#       2 lst = list(range(0, 10))
# ----> 3 rows = df.loc[lst, ['Year', 'Country']]
#
# AttributeError: 'list' object has no attribute 'loc'

# %%
#17
df.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-105-a42a655476f8> in <module>
#       1 #17
# ----> 2 df.isnull().sum()
#
# AttributeError: 'list' object has no attribute 'isnull'

# %%
df.dropna(inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-108-b5dde2205341> in <module>
# ----> 1 df.dropna(inplace=True)
#       2 df
#
# AttributeError: 'list' object has no attribute 'dropna'

# %%
len(df.columns)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-109-a3581ceb4a37> in <module>
# ----> 1 len(df.columns)
#
# AttributeError: 'list' object has no attribute 'columns'
